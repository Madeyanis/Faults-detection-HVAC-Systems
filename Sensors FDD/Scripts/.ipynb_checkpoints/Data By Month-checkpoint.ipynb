# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Janvier
mois = "1Janvier"
j1 = 30
j2 = 31

j1 = pd.read_csv(mois + "/" + "janvier" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "janvier" + str(j2) + ".csv",  index_col=[0])
janvier = pd.concat([j1, j2])
janvier.to_csv(mois + "/" + "Janvier.csv")

# %%
## Fevrier semaine 1
mois = "2Fevrier"
j1= 1
j1 = pd.read_csv(mois + "/" + "fevrier" + str(j1) + ".csv", index_col=[0])
j2= 2
j2 = pd.read_csv(mois + "/" + "fevrier" + str(j2) + ".csv", index_col=[0])
j3= 3
j3 = pd.read_csv(mois + "/" + "fevrier" + str(j3) + ".csv", index_col=[0])
j4= 4
j4 = pd.read_csv(mois + "/" + "fevrier" + str(j4) + ".csv", index_col=[0])
j5= 5
j5 = pd.read_csv(mois + "/" + "fevrier" + str(j5) + ".csv", index_col=[0])
j6= 6
j6 = pd.read_csv(mois + "/" + "fevrier" + str(j6) + ".csv", index_col=[0])
j7= 7
j7 = pd.read_csv(mois + "/" + "fevrier" + str(j7) + ".csv", index_col=[0])

S1 = pd.concat([j1, j2, j3, j4, j5, j6, j7])

## Fevrier semaine 2
j8= 8
j8 = pd.read_csv(mois + "/" + "fevrier" + str(j8) + ".csv", index_col=[0])
j9= 9
j9 = pd.read_csv(mois + "/" + "fevrier" + str(j9) + ".csv", index_col=[0])
j10= 10
j10 = pd.read_csv(mois + "/" + "fevrier" + str(j10) + ".csv", index_col=[0])
j11= 11
j11 = pd.read_csv(mois + "/" + "fevrier" + str(j11) + ".csv", index_col=[0])
j12= 12
j12 = pd.read_csv(mois + "/" + "fevrier" + str(j12) + ".csv", index_col=[0])
j13= 13
j13 = pd.read_csv(mois + "/" + "fevrier" + str(j13) + ".csv", index_col=[0])
j14= 14
j14 = pd.read_csv(mois + "/" + "fevrier" + str(j14) + ".csv", index_col=[0])

S2 = pd.concat([j8, j9, j10, j11, j12, j13, j14])

## Fevrier semaine 3
j15= 15
j15 = pd.read_csv(mois + "/" + "fevrier" + str(j15) + ".csv", index_col=[0])
j16= 16
j16 = pd.read_csv(mois + "/" + "fevrier" + str(j16) + ".csv", index_col=[0])
j17= 17
j17 = pd.read_csv(mois + "/" + "fevrier" + str(j17) + ".csv", index_col=[0])
j18= 18
j18 = pd.read_csv(mois + "/" + "fevrier" + str(j18) + ".csv", index_col=[0])
j19= 19
j19 = pd.read_csv(mois + "/" + "fevrier" + str(j19) + ".csv", index_col=[0])
j20= 20
j20 = pd.read_csv(mois + "/" + "fevrier" + str(j20) + ".csv", index_col=[0])
j21= 21
j21 = pd.read_csv(mois + "/" + "fevrier" + str(j21) + ".csv", index_col=[0])

S3 = pd.concat([j15, j16, j17, j18, j19, j20, j21])

## Fevrier semaine 4
j22= 22
j22 = pd.read_csv(mois + "/" + "fevrier" + str(j22) + ".csv", index_col=[0])
j23= 23
j23 = pd.read_csv(mois + "/" + "fevrier" + str(j23) + ".csv", index_col=[0])
j24= 24
j24 = pd.read_csv(mois + "/" + "fevrier" + str(j24) + ".csv", index_col=[0])
j25= 25
j25 = pd.read_csv(mois + "/" + "fevrier" + str(j25) + ".csv", index_col=[0])
j26= 26
j26 = pd.read_csv(mois + "/" + "fevrier" + str(j26) + ".csv", index_col=[0])
j27= 27
j27 = pd.read_csv(mois + "/" + "fevrier" + str(j27) + ".csv", index_col=[0])
j28= 28
j28 = pd.read_csv(mois + "/" + "fevrier" + str(j28) + ".csv", index_col=[0])

S4 = pd.concat([j22, j23, j24, j25, j26, j27, j28])

Fevrier = pd.concat([S1, S2, S3, S4])

Fevrier.to_csv('2Fevrier/Fevrier.csv')

# %%
f = pd.read_csv('2Fevrier/Fevrier.csv', index_col=[0])
f.shape
f.iloc[39000:40320]
# Out:
#                  Time   SA T  SA T Set    OA T   MA T   RA T  SA Fan Stat  \
# 120    2/28/2017 2:00  55.03     55.04  19.652  65.70  65.71            1
# 121    2/28/2017 2:01  55.03     55.04  19.616  65.69  65.71            1
# 122    2/28/2017 2:02  55.03     55.04  19.652  65.69  65.70            1
# 123    2/28/2017 2:03  55.03     55.04  19.688  65.68  65.70            1
# 124    2/28/2017 2:04  55.03     55.04  19.706  65.68  65.69            1
# ...               ...    ...       ...     ...    ...    ...          ...
# 1435  2/28/2017 23:55  54.99     55.04  51.854  66.77  66.75            1
# 1436  2/28/2017 23:56  54.99     55.04  51.872  66.74  66.71            1
# 1437  2/28/2017 23:57  54.99     55.04  51.908  66.70  66.68            1
# 1438  2/28/2017 23:58  54.99     55.04  51.926  66.67  66.66            1
# 1439  2/28/2017 23:59  54.99     55.04  51.962  66.64  66.63            1
#
#       RA Fan Stat  SA Speed  RA Speed  OA Damper  RA Damper  Cooling valve  \
# ...

# %%
## Mars
mois = "3Mars"
j1 = 1
j2 = 2
j3 = 3
j4 = 4
j5 = 5
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j12 = 12
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17
j18 = 18
j19 = 19


j1 = pd.read_csv(mois + "/" + "mars" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "mars" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "mars" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "mars" + str(j4) + ".csv",  index_col=[0])
j5 = pd.read_csv(mois + "/" + "mars" + str(j5) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "mars" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "mars" + str(j7) + ".csv",  index_col=[0])
j8 = pd.read_csv(mois + "/" + "mars" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "mars" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "mars" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "mars" + str(j11) + ".csv",  index_col=[0])
j12 = pd.read_csv(mois + "/" + "mars" + str(j12) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "mars" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "mars" + str(j14) + ".csv",  index_col=[0])
j15 = pd.read_csv(mois + "/" + "mars" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "mars" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "mars" + str(j17) + ".csv",  index_col=[0])
j18 = pd.read_csv(mois + "/" + "mars" + str(j18) + ".csv",  index_col=[0])
j19 = pd.read_csv(mois + "/" + "mars" + str(j19) + ".csv",  index_col=[0])

mars = pd.concat([j1, j2, j3, j4, j5, j6, j7, j8, j9, j10, j11, j12, j13, j14, j15, j16, j17, j18, j19])
mars.to_csv(mois + "/" + "Mars.csv")

# %%
## Mai
mois = "5Mai"
j2 = 2
j3 = 3
j4 = 4
j5 = 5
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j12 = 12
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17
j18 = 18
j19 = 19
j20 = 20
j21 = 21
j22 = 22
j23 = 23
j24 = 24
j25 = 25
j26 = 26
j27 = 27
j28 = 28
j29 = 29
j30 = 30
j31 = 31

j2 = pd.read_csv(mois + "/" + "Mai" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "Mai" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "Mai" + str(j4) + ".csv",  index_col=[0])
j5 = pd.read_csv(mois + "/" + "Mai" + str(j5) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "Mai" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "Mai" + str(j7) + ".csv",  index_col=[0])
#j8 = pd.read_csv(mois + "/" + "Mai" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "Mai" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "Mai" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "Mai" + str(j11) + ".csv",  index_col=[0])
j12 = pd.read_csv(mois + "/" + "Mai" + str(j12) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "Mai" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "Mai" + str(j14) + ".csv",  index_col=[0])
#j15 = pd.read_csv(mois + "/" + "Mai" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "Mai" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "Mai" + str(j17) + ".csv",  index_col=[0])
j18 = pd.read_csv(mois + "/" + "Mai" + str(j18) + ".csv",  index_col=[0])
j19 = pd.read_csv(mois + "/" + "Mai" + str(j19) + ".csv",  index_col=[0])
j20 = pd.read_csv(mois + "/" + "Mai" + str(j20) + ".csv",  index_col=[0])
j21 = pd.read_csv(mois + "/" + "Mai" + str(j21) + ".csv",  index_col=[0])
#j22 = pd.read_csv(mois + "/" + "Mai" + str(j22) + ".csv",  index_col=[0])
j23 = pd.read_csv(mois + "/" + "Mai" + str(j23) + ".csv",  index_col=[0])
j24 = pd.read_csv(mois + "/" + "Mai" + str(j24) + ".csv",  index_col=[0])
j25 = pd.read_csv(mois + "/" + "Mai" + str(j25) + ".csv",  index_col=[0])
j26 = pd.read_csv(mois + "/" + "Mai" + str(j26) + ".csv",  index_col=[0])
j27 = pd.read_csv(mois + "/" + "Mai" + str(j27) + ".csv",  index_col=[0])
j28 = pd.read_csv(mois + "/" + "Mai" + str(j28) + ".csv",  index_col=[0])
#j29 = pd.read_csv(mois + "/" + "Mai" + str(j29) + ".csv",  index_col=[0])
j30 = pd.read_csv(mois + "/" + "Mai" + str(j30) + ".csv",  index_col=[0])
j31 = pd.read_csv(mois + "/" + "Mai" + str(j31) + ".csv",  index_col=[0])

mars = pd.concat([j2, j3, j4, j5, j6, j7, j9, j10, j11, j12, j13, j14, j16, j17, j18, j19, j20, j21, j23, j24, j25, j26, j27, j28, j30, j31])
mars.to_csv(mois + "/" + "Mai.csv")

# %%
mars.plot(x='Time', y='OA T')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
## Juin

mois = "6Juin"
j1 = 1
j2 = 2
j3 = 3
j4 = 4
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17
j18 = 18

j1 = pd.read_csv(mois + "/" + "Juin" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "Juin" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "Juin" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "Juin" + str(j4) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "Juin" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "Juin" + str(j7) + ".csv",  index_col=[0])
j8 = pd.read_csv(mois + "/" + "Juin" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "Juin" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "Juin" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "Juin" + str(j11) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "Juin" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "Juin" + str(j14) + ".csv",  index_col=[0])
j15 = pd.read_csv(mois + "/" + "Juin" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "Juin" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "Juin" + str(j17) + ".csv",  index_col=[0])
j18 = pd.read_csv(mois + "/" + "Juin" + str(j18) + ".csv",  index_col=[0])


juin = pd.concat([j1, j2, j3, j4, j6, j7, j8, j9, j10, j11, j13, j14, j15, j16, j17, j18])
juin.to_csv(mois + "/" + "Juin.csv")

# %%
juin.plot(x='Time', y='OA T')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
## Juillet et Aout

mois = "7Juillet_8Aout"
j0 = 31
j1 = 1
j2 = 2
j3 = 3
j4 = 4
j5 = 5
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j12 = 12
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17
j18 = 18
j19 = 19
j20 = 20
j21 = 21
j22 = 22
j23 = 23
j24 = 24
j25 = 25
j26 = 26
j27 = 27
j28 = 28
j29 = 29
j30 = 30
j31 = 31

j0 = pd.read_csv(mois + "/" + "Juillet" + str(j0) + ".csv",  index_col=[0])
j1 = pd.read_csv(mois + "/" + "Aout" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "Aout" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "Aout" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "Aout" + str(j4) + ".csv",  index_col=[0])
j5 = pd.read_csv(mois + "/" + "Aout" + str(j5) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "Aout" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "Aout" + str(j7) + ".csv",  index_col=[0])
j8 = pd.read_csv(mois + "/" + "Aout" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "Aout" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "Aout" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "Aout" + str(j11) + ".csv",  index_col=[0])
j12 = pd.read_csv(mois + "/" + "Aout" + str(j12) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "Aout" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "Aout" + str(j14) + ".csv",  index_col=[0])
j15 = pd.read_csv(mois + "/" + "Aout" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "Aout" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "Aout" + str(j17) + ".csv",  index_col=[0])
j18 = pd.read_csv(mois + "/" + "Aout" + str(j18) + ".csv",  index_col=[0])
j19 = pd.read_csv(mois + "/" + "Aout" + str(j19) + ".csv",  index_col=[0])
j20 = pd.read_csv(mois + "/" + "Aout" + str(j20) + ".csv",  index_col=[0])
j21 = pd.read_csv(mois + "/" + "Aout" + str(j21) + ".csv",  index_col=[0])
j22 = pd.read_csv(mois + "/" + "Aout" + str(j22) + ".csv",  index_col=[0])
j23 = pd.read_csv(mois + "/" + "Aout" + str(j23) + ".csv",  index_col=[0])
j24 = pd.read_csv(mois + "/" + "Aout" + str(j24) + ".csv",  index_col=[0])
j25 = pd.read_csv(mois + "/" + "Aout" + str(j25) + ".csv",  index_col=[0])
j26 = pd.read_csv(mois + "/" + "Aout" + str(j26) + ".csv",  index_col=[0])
j27 = pd.read_csv(mois + "/" + "Aout" + str(j27) + ".csv",  index_col=[0])
j28 = pd.read_csv(mois + "/" + "Aout" + str(j28) + ".csv",  index_col=[0])
j29 = pd.read_csv(mois + "/" + "Aout" + str(j29) + ".csv",  index_col=[0])
j30 = pd.read_csv(mois + "/" + "Aout" + str(j30) + ".csv",  index_col=[0])
j31 = pd.read_csv(mois + "/" + "Aout" + str(j31) + ".csv",  index_col=[0])

J_A = pd.concat([j0, j1, j2, j3, j4, j5, j6, j7,j8, j9, j10, j11, j12, j13, j14, j15, j16, j17, j18, j19, j20, j21, j22, j23, j24, j25, j26, j27, j28, j29, j30, j31])
J_A.to_csv(mois + "/" + "Juillet_Aout.csv")

# %%
J_A.plot(x='Time', y='OA T')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
## Septembre et Octobre

mois = "9Septembre_10Octobre"
j1 = 1
j2 = 2
j3 = 3
j4 = 4
j5 = 5
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j12 = 12
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17
j30 = 30
j31 = 31

j1 = pd.read_csv(mois + "/" + "septembre" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "septembre" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "septembre" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "septembre" + str(j4) + ".csv",  index_col=[0])
j5 = pd.read_csv(mois + "/" + "septembre" + str(j5) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "septembre" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "septembre" + str(j7) + ".csv",  index_col=[0])
j8 = pd.read_csv(mois + "/" + "septembre" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "septembre" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "septembre" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "septembre" + str(j11) + ".csv",  index_col=[0])
j12 = pd.read_csv(mois + "/" + "septembre" + str(j12) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "septembre" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "septembre" + str(j14) + ".csv",  index_col=[0])
j15 = pd.read_csv(mois + "/" + "septembre" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "septembre" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "septembre" + str(j17) + ".csv",  index_col=[0])

j30 = pd.read_csv(mois + "/" + "octobre" + str(j30) + ".csv",  index_col=[0])
j31 = pd.read_csv(mois + "/" + "octobre" + str(j31) + ".csv",  index_col=[0])

so = pd.concat([j1, j2, j3, j4, j5, j6, j7,j8, j9, j10, j11, j12, j13, j14, j15, j16, j17, j30, j31])
so.to_csv(mois + "/" + "septembre_octobre.csv")

# %%
so.plot(x='Time', y='OA T')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
## Novembre

mois = "11Novembre"
j1 = 1
j2 = 2
j3 = 3
j4 = 4
j5 = 5
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j12 = 12
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17
j18 = 18
j19 = 19
j20 = 20
j21 = 21
j22 = 22
j23 = 23
j24 = 24
j25 = 25
j26 = 26
j27 = 27
j28 = 28
j29 = 29
j30 = 30

j1 = pd.read_csv(mois + "/" + "novembre" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "novembre" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "novembre" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "novembre" + str(j4) + ".csv",  index_col=[0])
j5 = pd.read_csv(mois + "/" + "novembre" + str(j5) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "novembre" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "novembre" + str(j7) + ".csv",  index_col=[0])
j8 = pd.read_csv(mois + "/" + "novembre" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "novembre" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "novembre" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "novembre" + str(j11) + ".csv",  index_col=[0])
j12 = pd.read_csv(mois + "/" + "novembre" + str(j12) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "novembre" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "novembre" + str(j14) + ".csv",  index_col=[0])
j15 = pd.read_csv(mois + "/" + "novembre" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "novembre" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "novembre" + str(j17) + ".csv",  index_col=[0])
j18 = pd.read_csv(mois + "/" + "novembre" + str(j18) + ".csv",  index_col=[0])
j19 = pd.read_csv(mois + "/" + "novembre" + str(j19) + ".csv",  index_col=[0])
j20 = pd.read_csv(mois + "/" + "novembre" + str(j20) + ".csv",  index_col=[0])
j21 = pd.read_csv(mois + "/" + "novembre" + str(j21) + ".csv",  index_col=[0])
j22 = pd.read_csv(mois + "/" + "novembre" + str(j22) + ".csv",  index_col=[0])
j23 = pd.read_csv(mois + "/" + "novembre" + str(j23) + ".csv",  index_col=[0])
j24 = pd.read_csv(mois + "/" + "novembre" + str(j24) + ".csv",  index_col=[0])
j25 = pd.read_csv(mois + "/" + "novembre" + str(j25) + ".csv",  index_col=[0])
j26 = pd.read_csv(mois + "/" + "novembre" + str(j26) + ".csv",  index_col=[0])
j27 = pd.read_csv(mois + "/" + "novembre" + str(j27) + ".csv",  index_col=[0])
j28 = pd.read_csv(mois + "/" + "novembre" + str(j28) + ".csv",  index_col=[0])
j29 = pd.read_csv(mois + "/" + "novembre" + str(j29) + ".csv",  index_col=[0])
j30 = pd.read_csv(mois + "/" + "novembre" + str(j30) + ".csv",  index_col=[0])


n = pd.concat([j1, j2, j3, j4, j5, j6, j7,j8, j9, j10, j11, j12, j13, j14, j15, j16, j17, j18, j19, j20, j21, j22, j23, j24, j25, j26, j27, j28, j29, j30])
n.to_csv(mois + "/" + "novembre.csv")

# %%
## Decembre

mois = "12Decembre"
j1 = 1
j2 = 2
j3 = 3
j4 = 4
j5 = 5
j6 = 6
j7 = 7
j8 = 8
j9 = 9
j10 = 10
j11 = 11
j12 = 12
j13 = 13
j14 = 14
j15 = 15
j16 = 16
j17 = 17

j1 = pd.read_csv(mois + "/" + "decembre" + str(j1) + ".csv",  index_col=[0])
j2 = pd.read_csv(mois + "/" + "decembre" + str(j2) + ".csv",  index_col=[0])
j3 = pd.read_csv(mois + "/" + "decembre" + str(j3) + ".csv",  index_col=[0])
j4 = pd.read_csv(mois + "/" + "decembre" + str(j4) + ".csv",  index_col=[0])
j5 = pd.read_csv(mois + "/" + "decembre" + str(j5) + ".csv",  index_col=[0])
j6 = pd.read_csv(mois + "/" + "decembre" + str(j6) + ".csv",  index_col=[0])
j7 = pd.read_csv(mois + "/" + "decembre" + str(j7) + ".csv",  index_col=[0])
j8 = pd.read_csv(mois + "/" + "decembre" + str(j8) + ".csv",  index_col=[0])
j9 = pd.read_csv(mois + "/" + "decembre" + str(j9) + ".csv",  index_col=[0])
j10 = pd.read_csv(mois + "/" + "decembre" + str(j10) + ".csv",  index_col=[0])
j11 = pd.read_csv(mois + "/" + "decembre" + str(j11) + ".csv",  index_col=[0])
j12 = pd.read_csv(mois + "/" + "decembre" + str(j12) + ".csv",  index_col=[0])
j13 = pd.read_csv(mois + "/" + "decembre" + str(j13) + ".csv",  index_col=[0])
j14 = pd.read_csv(mois + "/" + "decembre" + str(j14) + ".csv",  index_col=[0])
j15 = pd.read_csv(mois + "/" + "decembre" + str(j15) + ".csv",  index_col=[0])
j16 = pd.read_csv(mois + "/" + "decembre" + str(j16) + ".csv",  index_col=[0])
j17 = pd.read_csv(mois + "/" + "decembre" + str(j17) + ".csv",  index_col=[0])

d = pd.concat([j1, j2, j3, j4, j5, j6, j7,j8, j9, j10, j11, j12, j13, j14, j15, j16, j17])
d.to_csv(mois + "/" + "decembre.csv")

# %%
d.plot(x='Time', y='OA T')
# Out:
# <AxesSubplot:xlabel='Time'>
