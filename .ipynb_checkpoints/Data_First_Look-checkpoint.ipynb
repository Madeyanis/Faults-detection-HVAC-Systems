# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('MZVAV-1.csv')

# %%
data.head()
# Out:
#          Datetime  AHU: Supply Air Temperature  \
# 0  1/30/2017 0:00                        68.00
# 1  1/30/2017 0:01                        67.99
# 2  1/30/2017 0:02                        67.99
# 3  1/30/2017 0:03                        67.99
# 4  1/30/2017 0:04                        67.99
#
#    AHU: Supply Air Temperature Set Point  AHU: Outdoor Air Temperature  \
# 0                                  55.04                         32.00
# 1                                  55.04                         32.00
# 2                                  55.04                         -5.93
# 3                                  55.04                         -5.88
# 4                                  55.04                         -5.83
#
#    AHU: Mixed Air Temperature  AHU: Return Air Temperature  \
# 0                       68.00                        75.20
# 1                       66.71                        75.20
# 2                       66.71                        74.45
# ...

# %%
dates = data['Datetime']

# %%
jour1 = data.iloc[15*1440:16*1440]

# %%
jour1.plot(x='Datetime', y=['AHU: Outdoor Air Temperature', 'AHU: Supply Air Temperature'] ,figsize=(15, 8))
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
data['Datetime']
# Out:
# 0           1/30/2017 0:00
# 1           1/30/2017 0:01
# 2           1/30/2017 0:02
# 3           1/30/2017 0:03
# 4           1/30/2017 0:04
#                 ...
# 272155    12/17/2017 23:55
# 272156    12/17/2017 23:56
# 272157    12/17/2017 23:57
# 272158    12/17/2017 23:58
# 272159    12/17/2017 23:59
# Name: Datetime, Length: 272160, dtype: object

# %%
dates = data['Datetime']

# %%
c = 0
for i in dates:
    c = c + 1
    if i.split()[0].split('/')[0] == '2'  and i.split()[0].split('/')[1] == '9':
        print(i)
        break
# Out:
# 2/9/2017 0:00

# %%
dates.index[dates == '2/9/2017 00:00']
# Out:
# Int64Index([], dtype='int64')

# %%
c
# Out:
# 14401

# %%
Jj = data[0:0+1440]

# %%
Jj.plot(x='Datetime', y=['AHU: Outdoor Air Temperature', 'AHU: Supply Air Temperature'] ,figsize=(15, 8))
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
data.boxplot(column=['AHU: Outdoor Air Temperature', 'AHU: Return Air Temperature', 'AHU: Supply Air Temperature', 'AHU: Mixed Air Temperature'], figsize=(15, 8))
# Out:
# <AxesSubplot:>

# %%
cols = data.columns.tolist()
cols_new = ['Time', 'SA T', 'SA T Set', 'OA T', 'MA T', 'RA T',
            'SA Fan Stat', 'RA Fan Stat', 'SA Speed', 'RA Speed',
            'OA Damper', 'RA Damper', 'Cooling valve', 'Heating valve',
            'SA Pressure Set', 'SA Pressure', 'Occupancy', 'Fault']
dii = dict(zip(cols, cols_new))

# %%
data_corr = data.rename(columns=dii)
data_corr = data_corr.drop(columns=['SA T Set', 'SA Pressure Set'])

# %%
corr = data_corr.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e551f_row0_col0,#T_e551f_row1_col1,#T_e551f_row2_col2,#T_e551f_row3_col3,#T_e551f_row4_col4,#T_e551f_row4_col5,#T_e551f_row5_col4,#T_e551f_row5_col5,#T_e551f_row6_col6,#T_e551f_row6_col7,#T_e551f_row7_col6,#T_e551f_row7_col7,#T_e551f_row8_col8,#T_e551f_row9_col9,#T_e551f_row10_col10,#T_e551f_row11_col11,#T_e551f_row12_col12,#T_e551f_row13_col13,#T_e551f_row14_col14{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e551f_row0_col1,#T_e551f_row8_col12{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_e551f_row0_col2{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_e551f_row0_col3{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_e551f_row0_col4,#T_e551f_row0_col5,#T_e551f_row1_col10,#T_e551f_row9_col3,#T_e551f_row9_col12,#T_e551f_row11_col12,#T_e551f_row14_col12{
#             background-color:  #9dbdff;
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7e0421fbc4b2> in <module>
# ----> 1 plt.savefig(corr.style.background_gradient(cmap='coolwarm').set_precision(2), 'correlation.png')
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     935 def savefig(*args, **kwargs):
#     936     fig = gcf()
# --> 937     res = fig.savefig(*args, **kwargs)
#     938     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     939     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 were given
