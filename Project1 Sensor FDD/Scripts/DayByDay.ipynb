# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
j1 = 173+6+6
j2 = 174+6+6
j3 = 175+6+6
j4 = 176+6+6
j5 = 177+6+6
j6 = 178+6+5
jour1 = pd.read_csv('jour'+str(j1)+'.csv')
jour1 = jour1.drop(columns=['Unnamed: 0'])
jour2 = pd.read_csv('jour'+str(j2)+'.csv')
jour2 = jour2.drop(columns=['Unnamed: 0'])
jour3 = pd.read_csv('jour'+str(j3)+'.csv')
jour3 = jour3.drop(columns=['Unnamed: 0'])
jour4 = pd.read_csv('jour'+str(j4)+'.csv')
jour4 = jour4.drop(columns=['Unnamed: 0'])
jour5 = pd.read_csv('jour'+str(j5)+'.csv')
jour5 = jour5.drop(columns=['Unnamed: 0'])
jour6 = pd.read_csv('jour'+str(j6)+'.csv')
jour6 = jour6.drop(columns=['Unnamed: 0'])



fig, axes = plt.subplots(figsize=(17, 10), nrows=2, ncols=3)
jour1.plot(ax=axes[0, 0], x='Time', y=['OA T'])
jour2.plot(ax=axes[0, 1], x='Time', y=['OA T'])
jour3.plot(ax=axes[0, 2], x='Time', y=['OA T'])
jour4.plot(ax=axes[1, 0], x='Time', y=['OA T'])
jour5.plot(ax=axes[1, 1], x='Time', y=['OA T'])
jour6.plot(ax=axes[1, 2], x='Time', y=['OA T'])
# Out:
# <AxesSubplot:xlabel='Time'>
